# %%
import pandas as pd

# %%
df=pd.read_csv('setA.csv', index_col=0)

# %%
df.head(10)
# Out:
#                                  ID        C1        C2        C3        C4  \
# 0  d468a1f3b12a4fb28dfa957790c0688e  0.899548  0.595175 -0.418689  2.124562
# 1  ed7cfb9186af49ec9a4671bbe0b494b0  0.979140  1.518620 -1.611202  2.011399
# 2  bb5ce0943b044cf4a7161dbd47d993fa  0.693308 -1.675214  0.533730  1.312691
# 3  e0aa58dd0d5a4dcab715c65f0b04aa31 -1.179202 -8.207814 -5.431574 -5.059966
# 4  eb8bf002681c4785822ae3c2c8afa00c  0.948758  9.069630  3.772373  2.403791
# 5  10fb6b0184364c38b15b9a0b1b785288  2.133620  3.455416 -4.851605 -0.755191
# 6  03e3a46edd60422095ffaeff47c2bd5b -1.322893 -2.686340 -3.767863  4.568812
# 7  3623fda9eb2f479a8f6abf02be22acb5 -0.265528 -6.908037  6.966476  1.976503
# 8  51640e4f1e1e4c14a98f0e2c9293fe5e -0.406118 -3.418060 -3.335638 -3.669295
# 9  f62d772b73a5453a84f0cebbaf20887e -1.313670  3.773275 -8.265387 -0.013017
#
#          C5        C6        C7        C8         C9   ...           B5  \
# ...

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)
df
# Out:
#                                      ID        C1        C2         C3        C4        C5         C6        C7         C8         C9       C10        C11        C         A1        A2         A3        A4         A5        A6         A7         A8         A9       A10       A11        A        E1         E2         E3        E4         E5         E6         E7        E8         E9       E10       E11        E        B1        B2       B3         B4         B5        B6         B7        B8        B9        B10       B11        B12        B13        B
# ...

# %% [markdown]
# C:求欄1到欄11平均; A:求欄13到欄23平均 ; E:求欄25到欄35平均; B:求欄37到欄49平均;總平均

# %%
df['average_c'] = df[['C1', 'C2','C3','C4','C5','C6','C7','C8','C9','C10','C11']].mean(axis=1)

# %%
df.head(10)
# Out:
#                                  ID        C1        C2        C3        C4        C5        C6        C7        C8         C9       C10        C11        C         A1        A2         A3        A4        A5        A6        A7        A8        A9       A10       A11        A        E1         E2        E3        E4         E5        E6         E7        E8         E9       E10       E11        E        B1        B2       B3         B4        B5        B6        B7        B8        B9       B10       B11        B12        B13        B  average_c                                                                                                                                                                                                                                                                                                                                                                                                                                                              
# ...

# %%
df['average_a'] = df[['A1', 'A2','A3','A4','A5','A6','A7','A8','A9','A10','A11']].mean(axis=1)

# %%
df.head(10)
# Out:
#                                  ID        C1        C2        C3        C4        C5        C6        C7        C8         C9       C10        C11        C         A1        A2         A3        A4        A5        A6        A7        A8        A9       A10       A11        A        E1         E2        E3        E4         E5        E6         E7        E8         E9       E10       E11        E        B1        B2       B3         B4        B5        B6        B7        B8        B9       B10       B11        B12        B13        B  average_c  average_a                                                                                                                                                                                                                                                                                                                                                                                                                                                   
# ...

# %%
df['average_e'] = df[['E1', 'E2','E3','E4','E5','E6','E7','E8','E9','E10','E11']].mean(axis=1)

# %%
df.head(5)
# Out:
#                                  ID        C1        C2        C3        C4        C5        C6        C7        C8        C9       C10        C11        C        A1        A2         A3        A4        A5        A6        A7        A8        A9       A10       A11        A        E1         E2        E3        E4        E5        E6        E7        E8        E9       E10       E11        E        B1        B2       B3         B4        B5        B6        B7        B8        B9       B10       B11        B12       B13        B  average_c  average_a  average_e                                                                                                                                                                                                                                                                                                                                                                                                                                              
# ...

# %%
df['average_b'] = df[['B1', 'B2','B3','B4','B5','B6','B7','B8','B9','B10','B11','B12','B13']].mean(axis=1)

# %%
df.head(5)
# Out:
#                                  ID        C1        C2        C3        C4        C5        C6        C7        C8        C9       C10        C11        C        A1        A2         A3        A4        A5        A6        A7        A8        A9       A10       A11        A        E1         E2        E3        E4        E5        E6        E7        E8        E9       E10       E11        E        B1        B2       B3         B4        B5        B6        B7        B8        B9       B10       B11        B12       B13        B  average_c  average_a  average_e  average_b                                                                                                                                                                                                                                                                                                                                                                                                                                   
# ...

# %%
df['average'] = df[['C1', 'C2','C3','C4','C5','C6','C7','C8','C9','C10','C11','A1', 'A2','A3','A4','A5','A6','A7','A8','A9','A10','A11','E1', 'E2','E3','E4','E5','E6','E7','E8','E9','E10','E11','B1', 'B2','B3','B4','B5','B6','B7','B8','B9','B10','B11','B12','B13']].mean(axis=1)

# %%
df.head(5)
# Out:
#                                  ID        C1        C2        C3        C4        C5        C6        C7        C8        C9       C10        C11        C        A1        A2         A3        A4        A5        A6        A7        A8        A9       A10       A11        A        E1         E2        E3        E4        E5        E6        E7        E8        E9       E10       E11        E        B1        B2       B3         B4        B5        B6        B7        B8        B9       B10       B11        B12       B13        B                                                                                                                                                                                                                                                                                                                                                                                                                                                                               
# ...

# %%
new=df[['ID','average_c','average_a','average_e','average_b','average']].copy()

# %%
new.head(10)
# Out:
#                                  ID  average_c  average_a  average_e  average_b   average
# 0  d468a1f3b12a4fb28dfa957790c0688e -0.547949   1.813286   0.169208   2.273961   0.957056
# 1  ed7cfb9186af49ec9a4671bbe0b494b0  0.398635   1.776377  -1.617549  -0.078280   0.115394
# 2  bb5ce0943b044cf4a7161dbd47d993fa  0.325013   1.092096  -0.387497   0.585526   0.407823
# 3  e0aa58dd0d5a4dcab715c65f0b04aa31 -0.089270  -0.483380   1.484835  -1.397253  -0.149622
# 4  eb8bf002681c4785822ae3c2c8afa00c -0.874373   2.115756  -1.314097   0.993425   0.247139
# 5  10fb6b0184364c38b15b9a0b1b785288  0.090052   1.613393   0.446219  -0.346058   0.433191
# 6  03e3a46edd60422095ffaeff47c2bd5b -1.548905   1.740125  -0.111710  -0.625446  -0.147350
# 7  3623fda9eb2f479a8f6abf02be22acb5  0.053351   0.267993  -0.134150  -0.021927   0.039911
# 8  51640e4f1e1e4c14a98f0e2c9293fe5e  0.593477  -1.682527  -0.971685  -1.189686  -0.820985
# ...

# %%
new.to_csv('new.csv')
