# %% [markdown]
# datasetA.csv

# %%
import pandas as pd

# %%
df=pd.read_csv("datasetA.csv" , encoding='utf_8_sig')

# %% [markdown]
# 預設 pandas 為了節省時間，只會算大概的記憶體使用程度，但我們是要比較精確的數字，所以我們將 memory_usage='deep'

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 1 columns):
# ID|x00|x01|x02|x03|x04|x05|x06|x07|x08|x09|x10|x11|x12|x13|x14|x15|x16|x17|x18|x19|x20|x21|x22|x23|x24|x25|x26|x27|x28|x29|x30|x31|x32|x33|x34|x35|x36|x37|x38|x39|x40|x41|x42|x43|x44|x45|x46|x47|x48|x49    100000 non-null object
# dtypes: object(1)
# memory usage: 94.4 MB

# %% [markdown]
# 由上可知datatype是object，因為要進行計算的關係，在此先不轉為category

# %%
df.head(10)
# Out:
#   ID|x00|x01|x02|x03|x04|x05|x06|x07|x08|x09|x10|x11|x12|x13|x14|x15|x16|x17|x18|x19|x20|x21|x22|x23|x24|x25|x26|x27|x28|x29|x30|x31|x32|x33|x34|x35|x36|x37|x38|x39|x40|x41|x42|x43|x44|x45|x46|x47|x48|x49
# 0  d468a1f3b12a4fb28dfa957790c0688e|0.89954810016...
# 1  ed7cfb9186af49ec9a4671bbe0b494b0|0.97913998941...
# 2  bb5ce0943b044cf4a7161dbd47d993fa|0.69330753503...
# 3  e0aa58dd0d5a4dcab715c65f0b04aa31|-1.1792015854...
# 4  eb8bf002681c4785822ae3c2c8afa00c|0.94875793156...
# 5  10fb6b0184364c38b15b9a0b1b785288|2.13362048077...
# 6  03e3a46edd60422095ffaeff47c2bd5b|-1.3228927831...
# 7  3623fda9eb2f479a8f6abf02be22acb5|-0.2655284793...
# 8  51640e4f1e1e4c14a98f0e2c9293fe5e|-0.4061177668...
# 9  f62d772b73a5453a84f0cebbaf20887e|-1.3136699523...

# %% [markdown]
# 讀取前十筆資料，發現只有一個欄位，而且似乎有分隔線|，因此必須對做資料清理。
# When we read the data, we found there seems only one column; there is also a vertical-dash overthere, therefore, it must be cleaned.

# %%
df.columns=['ID']

# %%
df=df['ID'].str.split('|',expand=True)

# %%
pd.set_option("display.max_columns", None)
df
# Out:
#                                      0                     1   \
# 0      d468a1f3b12a4fb28dfa957790c0688e    0.8995481001634918
# 1      ed7cfb9186af49ec9a4671bbe0b494b0     0.979139989412422
# 2      bb5ce0943b044cf4a7161dbd47d993fa    0.6933075350334098
# 3      e0aa58dd0d5a4dcab715c65f0b04aa31    -1.179201585490276
# 4      eb8bf002681c4785822ae3c2c8afa00c    0.9487579315644278
# 5      10fb6b0184364c38b15b9a0b1b785288    2.1336204807794945
# 6      03e3a46edd60422095ffaeff47c2bd5b   -1.3228927831976873
# 7      3623fda9eb2f479a8f6abf02be22acb5  -0.26552847939327423
# 8      51640e4f1e1e4c14a98f0e2c9293fe5e   -0.4061177668242661
# 9      f62d772b73a5453a84f0cebbaf20887e   -1.3136699523446547
# 10     f9666f50bef54424817c58378178589f    0.1635512160959698
# 11     9fad9ab332ad4f18a21928d859a07884    -1.179272672237547
# 12     b8782eb52214435184c319797b7d445c  -0.22722013420677445
# 13     4fd6a298fa864846bfde2e3a502401eb    2.7901963982289737
# ...
